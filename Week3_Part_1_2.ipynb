# %%
import pandas as pd

# %%
# Creating dataframe
df = pd.read_csv('CanadaPostalCode.csv')
df = df[df.Borough != 'Not assigned']
df['Neighborhood'] = df.apply(lambda row: row['Borough'] if row['Neighborhood'] == 'Not assigned' else row['Neighborhood'], axis = 1)
df.columns = ['PostalCode', 'Borough', 'Neighborhood']
df = df.reset_index(drop = True)

# %%
# displaying dataframe for Part 1
df
# Out:
#     PostalCode           Borough  \
# 0          M2L        North York
# 1          M2P        North York
# 2          M4C         East York
# 3          M1G       Scarborough
# 4          M2R        North York
# 5          M2N        North York
# 6          M2M        North York
# 7          M1R       Scarborough
# 8          M9N              York
# 9          M9P         Etobicoke
# 10         M9B         Etobicoke
# 11         M4A        North York
# 12         M1X       Scarborough
# 13         M5S  Downtown Toronto
# 14         M5K  Downtown Toronto
# 15         M4H         East York
# 16         M8X         Etobicoke
# 17         M4K      East Toronto
# 18         M4E      East Toronto
# 19         M5R   Central Toronto
# 20         M4V   Central Toronto
# 21         M4M      East Toronto
# 22         M5W  Downtown Toronto
# 23         M1W       Scarborough
# 24         M4X  Downtown Toronto
# 25         M5C  Downtown Toronto
# 26         M9V         Etobicoke
# ...

# %%
#checking shape for the dataframe
df.shape
# Out:
# (103, 3)

# %%
#loading coordinates
coordinates = pd.read_csv('http://cocl.us/Geospatial_data')
dataframe = pd.merge(df, coordinates, left_on = 'PostalCode', right_on = 'Postal Code')
dataframe.drop(columns=['Postal Code'], inplace = True)
dataframe
# Out:
#     PostalCode           Borough  \
# 0          M2L        North York
# 1          M2P        North York
# 2          M4C         East York
# 3          M1G       Scarborough
# 4          M2R        North York
# 5          M2N        North York
# 6          M2M        North York
# 7          M1R       Scarborough
# 8          M9N              York
# 9          M9P         Etobicoke
# 10         M9B         Etobicoke
# 11         M4A        North York
# 12         M1X       Scarborough
# 13         M5S  Downtown Toronto
# 14         M5K  Downtown Toronto
# 15         M4H         East York
# 16         M8X         Etobicoke
# 17         M4K      East Toronto
# 18         M4E      East Toronto
# 19         M5R   Central Toronto
# 20         M4V   Central Toronto
# 21         M4M      East Toronto
# 22         M5W  Downtown Toronto
# 23         M1W       Scarborough
# 24         M4X  Downtown Toronto
# 25         M5C  Downtown Toronto
# 26         M9V         Etobicoke
# ...

# %%
# Filtering Toronto Boroughs
df_toronto = dataframe[dataframe['Borough'].str.contains("Toronto")].reset_index(drop=True)
df_toronto.head()
# Out:
#   PostalCode           Borough                              Neighborhood  \
# 0        M5S  Downtown Toronto            University of Toronto, Harbord
# 1        M5K  Downtown Toronto  Toronto Dominion Centre, Design Exchange
# 2        M4K      East Toronto              The Danforth West, Riverdale
# 3        M4E      East Toronto                               The Beaches
# 4        M5R   Central Toronto       The Annex, North Midtown, Yorkville
#
#     Latitude  Longitude
# 0  43.662696 -79.400049
# 1  43.647177 -79.381576
# 2  43.679557 -79.352188
# 3  43.676357 -79.293031
# 4  43.672710 -79.405678
